# %% [markdown]
# <a href="https://colab.research.google.com/github/zalihat/Python-for-data-science-resources/blob/master/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics
# **Prepared by: Zalihat Mohammed**

# %% [markdown]
# ## Python syntax
# The syntax of the Python programming language is the set of rules that defines how a Python program will be written and interpreted.
#
# Even human languages such as English have syntaxes that we learn through the subject called grammar. It teaches us how to properly place each part of speech in the sentence to make it meaningful.
#
# Without syntax, it is nearly impossible to make the interpreter understand what the programmer wants to convey to the computer through the logical codes.
#
# Learning syntaxes for different programming languages might seem daunting. But understanding where and why they are required and regular practice of them will help beginners keep in mind the syntactic structure of each and every concept they learn. In the beginning, the learning might go slow, but as you become more familiar with the language, learning different programming languages will not be a tough nut to crack.
#
# Reference:
# 1. https://www.stechies.com/python-syntax/
# 2. https://en.wikipedia.org/wiki/

# %% [markdown]
# The print() function
# It prints the specified message to the screen, or other standard output device. The message can be a string, or any other object, the object will be converted into a string before written to the screen.
#  You will learn more about strings and other data type in the coming section.

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ## Python variables
# Python variables are the reserved memory locations used to store values with in a Python Program. This means that when you create a variable you reserve some space in the memory.
#
# Variables are like containers, once created you can store values in them and can also retrieve values from them.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Create a variable in python**

# %%
age = 21

# %% [markdown]
# Using the print statement we can output the value of the variable 'age' on the screen.

# %%
print(age)
# Out:
# 21

# %% [markdown]
# In Jupyter notebook please note that you can print a variable to the screen without using the print function print() as shown below.
# However this only applies when the statement is the last one in the cell

# %%
age
# Out:
# 21

# %% [markdown]
# ## Python comments
# In computer programming, comments are hints that we use to make our code more understandable.
#
# 1. Comments can be used to explain Python code.
#
# 2. Comments can be used to make the code more readable.
#
# 3. Comments can be used to prevent execution when testing code.
#
# Any statement that starts with the symbol # is a comment and is ignored by the interpreter.

# %%
# This is a comment
print('This is not a comment')
# Out:
# This is not a comment

# %% [markdown]
# ## Python indentation
# Python indentation refers to adding white space before a statement to a particular block of code. In another word, all the statements with the same space to the right, belong to the same code block.
#
# You will learn more about indentation in later section.

# %% [markdown]
# ## Python data types
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Text Type:	str
#
# Note: Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# Numeric Types:	int, float, complex
#
# Sequence Types:	list, tuple, range
#
# Mapping Type:	dict
#
# Boolean Type:	bool
#
#
# We will look at more complex datatypes like sequences and mapping in a later section.

# %%
# string
print('Hello world')
# Out:
# Hello world

# %%
#integer
print(12)
# Out:
# 12

# %%
# float 
print(12.9)
# Out:
# 12.9

# %%
# Boolean
print(True)
# Out:
# True

# %% [markdown]
# ## Python operators
# Python Operators in general are used to perform operations on values and variables. These are standard symbols used for the purpose of logical and arithmetic operations.
#
# OPERATORS: Are the special symbols. Eg -, +, *, /, etc.
# OPERAND: It is the value on which the operator is applied.
#
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication and division.
#
# There are 7 arithmetic operators in Python:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus(%)
# 6. Exponentiation (**)
# 7. Floor division (//)
#
# ![image.png](data:image/png;base64,...)

# %%
x = 20
y = 5
z = 12

# %%
# addition operation
add_op = x + y
print(add_op)
# Out:
# 25

# %%
# subtraction operation
sub_op = x - y
print(sub_op)
# Out:
# 15

# %%
# multiplication operation
mult_op = x * y
print(mult_op)
# Out:
# 100

# %%
# division (float) operation
div_op = x / z
print(div_op)
# Out:
# 1.6666666666666667

# %%
# division(floor) operation
div_op_floor = x // z
print(div_op_floor)
# Out:
# 1

# %%
# Modulus operation
Modulus_op = x % z
print(Modulus_op)
# Out:
# 8

# %%
# Power operation
pow_op = x**2
print(pow_op)
# Out:
# 400

# %% [markdown]
# ## Built in functions in python
# In Python, a function is a group of related statements that performs a specific task.
#
# Mainly, there are two types of functions:
#
# **User-defined functions** – These functions are defined by the user to perform a specific task.
#
# **Built-in functions** – These functions are pre-defined functions in Python.
#
# In a later section we will see how to create an use our own function(user defined functions), but for now lets look at how to use python built in function.
#
# **print() function**
#
# The print() function prints the specified message to the screen or another standard output device.
#
# **type() function**
#
# The type() function returns the type of the specified object.
#
# **input() function**
#
# The input() function allows taking input from the user.
#
# **abs() function**
#
# The abs() function returns the absolute value of the specified number.

# %%
#print function
print('Hi zee')
# Out:
# Hi zee

# %%
#type function
salary = 3000
type(salary)
# Out:
# int

# %%
input()
# Out:
# Nothing
# 'Nothing'

# %%
score = -4
abs(score)
# Out:
# 4

# %% [markdown]
# ## Activity
# 1. Show examples of five other built in functions in python.
# 2. Create a variable c whose value is 10 square modulus 15
# (Use BODMAS rule), then print  c
